# %% [markdown]
# <a href="https://colab.research.google.com/github/Fjflorez1990/Programa-git/blob/main/PruebaProyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

datos2018 = pd.read_excel('2018.xlsx',skiprows=7)
#print(datos2018.columns)

'''
Index(['Código de la Institución', 'IES_PADRE',
       'Institución de Educación Superior (IES)', 'Principal o Seccional',
       'ID Sector IES', 'Sector IES', 'ID Caracter', 'Caracter IES',
       'Código del departamento (IES)', 'Departamento de domicilio de la IES',
       'Código del municipio', 'Municipio de domicilio de la IES',
       'Código SNIES del programa', 'Programa Académico', 'ID Nivel Académico',
       'Nivel Académico', 'ID Nivel de Formación', 'Nivel de Formación',
       'ID Metodología', 'Metodología', 'ID Área', 'Área de Conocimiento',
       'ID Núcleo', 'Núcleo Básico del Conocimiento (NBC)',
       'Código del Departamento (Programa)',
       'Departamento de Oferta del Programa',
       'Código del Municipio (Programa)', 'Municipio de Oferta del Programa',
       'ID Sexo', 'Sexo', 'Año', 'Semestre', 'Graduados'],
      dtype='object')
'''

#print(datos2018.head())

'''
   Código de la Institución  IES_PADRE  \
0                      1101       1101
1                      1101       1101
2                      1101       1101
3                      1101       1101
4                      1101       1101

  Institución de Educación Superior (IES) Principal o Seccional  \
0        UNIVERSIDAD NACIONAL DE COLOMBIA             Principal
1        UNIVERSIDAD NACIONAL DE COLOMBIA             Principal
2        UNIVERSIDAD NACIONAL DE COLOMBIA             Principal
3        UNIVERSIDAD NACIONAL DE COLOMBIA             Principal
4        UNIVERSIDAD NACIONAL DE COLOMBIA             Principal

   ID Sector IES Sector IES  ID Caracter Caracter IES  \
0              1    OFICIAL            4  Universidad
1              1    OFICIAL            4  Universidad
2              1    OFICIAL            4  Universidad
3              1    OFICIAL            4  Universidad
4              1    OFICIAL            4  Universidad

   Código del departamento (IES) Departamento de domicilio de la IES  ...  \
0                             11                          BOGOTA D.C  ...
1                             11                          BOGOTA D.C  ...
2                             11                          BOGOTA D.C  ...
3                             11                          BOGOTA D.C  ...
4                             11                          BOGOTA D.C  ...

       Núcleo Básico del Conocimiento (NBC)  \
0  Ingeniería agronómica, pecuaria y afines
1  Ingeniería agronómica, pecuaria y afines
2  Ingeniería agronómica, pecuaria y afines
3  Ingeniería agronómica, pecuaria y afines
4                      Medicina veterinaria

  Código del Departamento (Programa)  Departamento de Oferta del Programa  \
0                                 11                           BOGOTA D.C
1                                 11                           BOGOTA D.C
2                                 11                           BOGOTA D.C
3                                 11                           BOGOTA D.C
4                                 11                           BOGOTA D.C

  Código del Municipio (Programa)  Municipio de Oferta del Programa ID Sexo  \
0                           11001                       BOGOTA D.C.       1
1                           11001                       BOGOTA D.C.       1
2                           11001                       BOGOTA D.C.       2
3                           11001                       BOGOTA D.C.       2
4                           11001                       BOGOTA D.C.       1

     Sexo   Año  Semestre Graduados
0  Hombre  2018         1        16
1  Hombre  2018         2        35
2   Mujer  2018         1        17
3   Mujer  2018         2        12
4  Hombre  2018         1         8

[5 rows x 33 columns]

__________________________________________________

(1)PRIMERO
                             Área de Conocimiento
0     Ingeniería, arquitectura, urbanismo y afines.          // FILTRAR POR ESTA


(2)SEGUNDO
                   Núcleo Básico del Conocimiento (NBC)
100         Ingeniería de sistemas, telemática y afines      // FILTRAR POR ESTA
366   Ingeniería electrónica, telecomunicaciones y afines    // FILTRAR POR ESTA


(3)TERCERO
      Departamento de Oferta del Programa
4501                            ATLANTICO.                   // FILTRAR POR ESTA, porque mcuhas ofertas en este departamento no tienen sede en el mismo


(4)CUARTO
      Departamento de domicilio de la IES
4501                            ATLANTICO                    // el peso de los otro domicilios frente al atlantico


'''
# Imprime los valores únicos

#columnasSelec2018 = datos2018[['Departamento de Oferta del Programa']]
#valores_unicos = columnasSelec2018.drop_duplicates()
#print(valores_unicos)

#Imprime las carreras unicas del ares de las TICs (se deben buscar las que si correspondan)
#df_filtrado_1 = datos2018[datos2018['Departamento de Oferta del Programa'] == 'ATLANTICO']
#df_filtrado_2 = df_filtrado_1[(df_filtrado_1['Núcleo Básico del Conocimiento (NBC)'] == 'Ingeniería de sistemas, telemática y afines') | (df_filtrado_1['Núcleo Básico del Conocimiento (NBC)'] == 'Ingeniería electrónica, telecomunicaciones y afines')]
#valores_unicos = df_filtrado_2['Programa Académico'].unique()
#print(valores_unicos)

'''
['ADMINISTRACION DE SISTEMAS INFORMATICOS' OK
  'INGENIERIA ELECTRONICA' OK
 'ESPECIALIZACION EN INGENIERIA DEL SOFTWARE' OK
 'MAESTRIA EN INGENIERIA DE SISTEMAS Y COMPUTACION' OK
 'MAESTRÍA EN INGENIERÍA ELECTRÓNICA' OK
 'MAESTRIA EN TELEMATICA Y TELECOMUNICACIONES' OK
 'MAESTRÍA EN GOBIERNO DE TECNOLOGÍA INFORMÁTICA' OK
 'DOCTORADO EN INGENIERÍA DE SISTEMAS Y COMPUTACIÓN' OK
 'INGENIERIA DE SISTEMAS Y COMPUTACION' OK
 'ESPECIALIZACIÓN EN GERENCIA DE TECNOLOGÍAS DE LA INFORMACIÓN' OK
 'INGENIERIA DE SISTEMAS' OK
  'INGENIERIA ELECTRONICA Y TELECOMUNICACIONES' OK
 'TECNOLOGIA EN ANALISIS Y DISEÑO DE SISTEMAS Y COMPUTACION' OK
 'INGENIERÍA DE SISTEMAS' OK
  'TECNOLOGIA DE SISTEMAS' OK
 'TECNOLOGIA EN ELECTRONICA' ??
  'TECNOLOGIA DE AUDIO' ??
 'ESPECIALIZACIÓN EN SEGURIDAD INFORMÁTICA' OK
 'MAESTRÍA EN GESTIÓN DE TECNOLOGÍA DE INFORMACIÓN' OK
 'MAESTRÍA EN INGENIERÍA DE SISTEMAS Y COMPUTACIÓN' OK
 'ESPECIALIZACIÓN EN COMUNICACIONES MÓVILES E INALÁMBRICAS' OK
 'ESPECIALIZACIÓN EN AUTOMATIZACIÓN Y CONTROL INDUSTRIAL' OK
 'MAESTRIA EN INGENIERIA' ??
  'ESPECIALIZACION EN GERENCIA INFORMATICA' OK
 'TECNOLOGIA EN SISTEMAS' OK
  'TECNOLOGIA EN DESARROLLO DE SOFTWARE' OK
 'TECNOLOGIA EN GESTION DE REDES INFORMÁTICAS' OK
 'TECNOLOGIA NAVAL EN ELECTRONICA' OK
  'TECNOLOGIA EN INFORMATICA' OK
 'TECNICO PROFESIONAL EN ELECTRONICA' ??
 'TÉCNICA PROFESIONAL EN MANTENIMIENTO ELECTRÓNICO INDUSTRIAL' ??
 'TECNOLOGIA EN AUTOMATIZACIÓN ELECTRÓNICA INDUSTRIAL' OK
 'TECNICA PROFESIONAL EN MANTENIMIENTO DE SISTEMAS INFORMATICOS' OK
 'TECNOLOGIA EN GESTIÓN DE REDES DE TELECOMUNICACIONES' OK
 'TÉCNICA PROFESIONAL EN INSTALACIÓN Y MANTENIMIENTO DE REDES DE TELECOMUNICACIONES' OK
 'INGENIERIA TELEMÁTICA' OK
 'TECNOLOGIA EN ELECTRONICA Y CONTROLES INDUSTRIALES' ??
 'TECNOLOGÍA EN ELECTRONICA Y TELECOMUNICACIONES' OK
  'INGENIERÍA ELECTRÓNICA' OK
 'TECNOLOGIA EN DESARROLLO DE SISTEMAS ELECTRÓNICOS' ??
 'TECNOLOGÍA EN DESARROLLO DE SOFTWARE' OK
 'TECNOLOGÍA EN ANALISIS Y DESARROLLO DE SISTEMAS DE INFORMACION' OK
 'TECNOLOGÍA EN AUTOMATIZACION INDUSTRIAL' OK
 'TECNOLOGÍA EN DESARROLLO DE VIDEOJUEGOS' OK
 'TECNOLOGÍA EN PRODUCCIÓN DE MULTIMEDIA' OK
 'TECNOLOGÍA EN GESTIÓN DE REDES DE DATOS' OK
 'TECNOLOGÍA EN MANTENIMIENTO DE EQUIPOS DE CÓMPUTO DISEÑO E INSTALACIÓN DE CABLEADO ESTRUCTURADO' OK
 'TECNOLOGÍA PRODUCCIÓN DE MULTIMEDIA' OK
 'TECNOLOGÍA EN ANÁLISIS Y DESARROLLO DE SISTEMAS DE INFORMACIÓN' OK
 'ESPECIALIZACION EN SEGURIDAD INFORMATICA' OK
 'TECNICA PROFESIONAL EN PROGRAMACION DE COMPUTADORES' OK]
'''


#datos2019 = pd.read_excel('2019.xlsx')
#print(datos2019.describe())
#print(datos2019.columns)
# Out:
# ['ADMINISTRACION DE SISTEMAS INFORMATICOS' 'INGENIERIA ELECTRONICA'
#  'ESPECIALIZACION EN INGENIERIA DEL SOFTWARE'
#  'MAESTRIA EN INGENIERIA DE SISTEMAS Y COMPUTACION'
#  'MAESTRÍA EN INGENIERÍA ELECTRÓNICA'
#  'MAESTRIA EN TELEMATICA Y TELECOMUNICACIONES'
#  'MAESTRÍA EN GOBIERNO DE TECNOLOGÍA INFORMÁTICA'
#  'DOCTORADO EN INGENIERÍA DE SISTEMAS Y COMPUTACIÓN'
#  'INGENIERIA DE SISTEMAS Y COMPUTACION'
#  'ESPECIALIZACIÓN EN GERENCIA DE TECNOLOGÍAS DE LA INFORMACIÓN'
#  'INGENIERIA DE SISTEMAS' 'INGENIERIA ELECTRONICA Y TELECOMUNICACIONES'
#  'TECNOLOGIA EN ANALISIS Y DISEÑO DE SISTEMAS Y COMPUTACION'
#  'INGENIERÍA DE SISTEMAS' 'TECNOLOGIA DE SISTEMAS'
#  'TECNOLOGIA EN ELECTRONICA' 'TECNOLOGIA DE AUDIO'
#  'ESPECIALIZACIÓN EN SEGURIDAD INFORMÁTICA'
#  'MAESTRÍA EN GESTIÓN DE TECNOLOGÍA DE INFORMACIÓN'
#  'MAESTRÍA EN INGENIERÍA DE SISTEMAS Y COMPUTACIÓN'
#  'ESPECIALIZACIÓN EN COMUNICACIONES MÓVILES E INALÁMBRICAS'
#  'ESPECIALIZACIÓN EN AUTOMATIZACIÓN Y CONTROL INDUSTRIAL'
# ...
